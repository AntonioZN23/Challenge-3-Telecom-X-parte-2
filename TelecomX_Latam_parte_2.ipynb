# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioZN23/Challenge-3-Telecom-X-parte-2/blob/main/TelecomX_Latam_parte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
archivo = '/content/drive/MyDrive/Alura Challenge TelecomX/TelecomX_Data.json'
df = pd.read_json(archivo)
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
#Visualizar diccionario
df['customer'][1]
# Out:
# {'gender': 'Male',
#  'SeniorCitizen': 0,
#  'Partner': 'No',
#  'Dependents': 'No',
#  'tenure': 9}

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
#Visualizar datos
for i in df.columns[:2]:
  print(df[i].info())
  print(df[i].unique())
  print('\n')
for j in df.columns[2:]:
  print(j,'\n')
  df_variable = pd.json_normalize(df[j])
  df_variable.info()
  print('\n')
  lista = list(df_variable.columns)
  for i in lista:
    print(i,' : ',pd.unique(df_variable[i]))
  print('\n')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: customerID
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB
# None
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB
# None
# ['No' 'Yes' '']
#
#
# customer
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# ...

# %%
#Normalizar datos y actualizar DF
lista = df.columns[2:]
for j in lista:
  df_variable = pd.json_normalize(df[j])
  df = df.join(df_variable)
  df = df.drop(j,axis='columns')

df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# #🔧 Transformación

# %%
df['Charges.Total'] = df[['Charges.Total']].map(lambda x: x.replace('$','').replace(',','').strip())
df['Charges.Total'] = pd.to_numeric(df['Charges.Total']).astype(np.float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
valores = list(df['Charges.Monthly']/30)

# %%
df = df.join(pd.DataFrame(data=valores,columns=['Cuentas_Diarias'],index=df.index,dtype=(np.float64)))
df.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
#Se verifica la cantidad de espacios vacíos y si es menor al 5% se elimina
columnas_si_a_numero = ['Churn','Partner','Dependents','PhoneService',]

for j in columnas_si_a_numero:
  df[j] = df[j].str.lower()
  df[j] = df[j].str.strip('')
  if (df[j].map({'yes':1,'no':0}).isna().sum() / (df.size/len(df.columns))) <= 0.05:
    for i in df.index:
      if df[j][i] == '':
        df = df.drop(i,axis='index')
  df[j] = df[j].map({'yes':1,'no':0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   int64
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   int64
#  5   Dependents        7043 non-null   int64
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   int64
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
df.describe()
# Out:
#              Churn  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.265370       0.162147     0.483033     0.299588    32.371149
# std       0.441561       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       0.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  Charges.Monthly  Charges.Total  Cuentas_Diarias
# count   7043.000000      7043.000000    7032.000000      7043.000000
# mean       0.903166        64.761692    2283.300441         2.158723
# std        0.295752        30.090047    2266.771362         1.003002
# ...

# %%
dicc = {'Situacion':[int((df.size/len(df.columns))-(df['Churn'].sum())),int(df['Churn'].sum())]}
df_churn = pd.DataFrame(data=dicc, index=['No Churn', 'Churn'])

# %%
#General
fig, ax = plt.subplots(figsize=(8,4))
ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.tick_params(axis='y',which='both',size=0)
ax = sns.barplot(data=df_churn,x='Situacion',y=df_churn.index,hue=df_churn.index,orient = 'h',
                  palette='Paired',legend=False)
ax.set_title(label='Situación de abandono de clientes',
      loc='left',fontsize=16)
ax.set_ylabel('Situación')
for i,j in enumerate(df_churn['Situacion']):
  ax.text(j+20,i,str(j),color='black',fontsize=8.5,ha='left',va='center')
plt.show()

# %%
dicc_2 = {'Situacion_por_Genero':[0,0,0,0]}
#Hombres vs Mujeres
for i in df.index:
  if df['gender'][i] == 'Male' and df['Churn'][i] == 0:
    dicc_2['Situacion_por_Genero'][0] += 1
  elif df['gender'][i] == 'Male' and df['Churn'][i] == 1:
    dicc_2['Situacion_por_Genero'][1] += 1
  elif df['gender'][i] == 'Female' and df['Churn'][i] == 0:
    dicc_2['Situacion_por_Genero'][2] += 1
  elif df['gender'][i] == 'Female' and df['Churn'][i] == 1:
    dicc_2['Situacion_por_Genero'][3] += 1

indice = ['Estancia de Hombres', 'Evasión de Hombres', 'Estancia de Mujeres', 'Evasión de Mujeres']
df_churn_por_genero = pd.DataFrame(data=dicc_2, index=indice)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.tick_params(axis='y',which='both',size=0)
ax = sns.barplot(data=df_churn_por_genero,x='Situacion_por_Genero',y=df_churn_por_genero.index,hue=df_churn_por_genero.index,orient = 'h',
                  palette='Paired',legend=False)
ax.set_title(label='Situación de abandono de clientes por género',
      loc='left',fontsize=16)
ax.set_ylabel('Situación por genero')
for i,j in enumerate(df_churn_por_genero['Situacion_por_Genero']):
  ax.text(j+20,i,str(j),color='black',fontsize=8.5,ha='left',va='center')
plt.show()

# %%
senior_churn = df.groupby(['SeniorCitizen', 'Churn']).size().reset_index(name='total')
senior_churn['SeniorCitizen']=senior_churn['SeniorCitizen'].map({0:'No Senior',1:'Senior'})
senior_churn['Churn']=senior_churn['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.barplot(data=senior_churn,x='SeniorCitizen',y='total',hue='Churn',palette='Set2')

plt.title('Cantidad de abandono según si es Senior Citizen o no', loc='left', fontsize=14)
plt.xlabel('Senior Citizen')
plt.ylabel('Cantidad de clientes')

plt.show()

# %%
churn_contrato = df.groupby(['Contract', 'Churn']).size().reset_index(name='total')
churn_contrato['Churn']=churn_contrato['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.barplot(data=churn_contrato,x='Contract',y='total',hue='Churn',palette='Set1')

plt.title('Cantidad de abandono según tipo de contrato', loc='left', fontsize=14)
plt.xlabel('Tipo de contrato')
plt.ylabel('Cantidad de clientes')

plt.show()

# %%
churn_pareja = df.groupby(['Partner', 'Churn']).size().reset_index(name='total')
churn_pareja['Partner']=churn_pareja['Partner'].map({0:'Sin pareja',1:'Con pareja'})
churn_pareja['Churn']=churn_pareja['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.barplot(data=churn_pareja,x='Partner',y='total',hue='Churn',palette='Set3')

plt.title('Cantidad de abandono según pareja', loc='left', fontsize=14)
plt.xlabel('Tipo de contrato')
plt.ylabel('Cantidad de clientes')

plt.show()

# %%
churn_metodo_pago = df.groupby(['PaymentMethod', 'Churn']).size().reset_index(name='total')
churn_metodo_pago['Churn']=churn_metodo_pago['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.barplot(data=churn_metodo_pago,x='total',y='PaymentMethod',hue='Churn',palette='Set2',orient='h')

plt.title('Cantidad de abandono según metodo de pago', loc='left', fontsize=14)
plt.xlabel('Total de clientes')
plt.ylabel('Método de pago')

plt.show()

# %%
df = df.rename(columns={'Charges.Total':'Cargos Totales'})

churn_total_gastado = df.groupby(['Cargos Totales', 'Churn']).size().reset_index(name='total')
churn_total_gastado['Churn']=churn_total_gastado['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.boxplot(x='Churn', y='Cargos Totales', data=churn_total_gastado,color='green')
plt.title('Distribución del Abandono según Total Gastado')
plt.show()

# %%
df = df.rename(columns={'Charges.Monthly':'Cargos Mensuales'})

churn_total_gastado = df.groupby(['Cargos Mensuales', 'Churn']).size().reset_index(name='total')
churn_total_gastado['Churn']=churn_total_gastado['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.boxplot(x='Churn', y='Cargos Mensuales', data=churn_total_gastado,color='purple')
plt.title('Distribución del Abandono según Gasto Mensual')
plt.show()

# %%
df = df.rename(columns={'Cuentas_Diarias':'Cargos Diarios'})

churn_total_gastado = df.groupby(['Cargos Diarios', 'Churn']).size().reset_index(name='total')
churn_total_gastado['Churn']=churn_total_gastado['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.boxplot(x='Churn', y='Cargos Diarios', data=churn_total_gastado,color='blue')
plt.title('Distribución del Abandono según Gasto Diario')
plt.show()

# %%
df = df.rename(columns={'tenure':'tiempo'})

churn_total_gastado = df.groupby(['tiempo', 'Churn']).size().reset_index(name='total')
churn_total_gastado['Churn']=churn_total_gastado['Churn'].map({0:'Se mantiene',1:'Abandonó'})

sns.boxplot(x='Churn', y='tiempo', data=churn_total_gastado,color='red')
plt.title('Distribución del Abandono según Tiempo de tenencia')
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## Introducción
# Se realizó una evaluación como asistente de análisis de datos en la empresa Telecom X dentro del proyecto "Churn de Clientes". Mediante el presente proyecto se busca determinar las causas del alto índice de abandono de los clientes al realizar un Análisis Exploratorio de Datos, para lo cual fue proporcionada una base de datos de la empresa, la cual pasó por un procedimiento de ETL para poder ser analizada.
# ________________________________________________________________________________
#
# ## Tratamiento de datos
# La información proporcionada fue mediante un documento JSON, el método de extracción fue realizado utilizando la librería Pandas para la generación del Data Frame (DF). El DF resultante requirió un tratamiento para el acomodo de los diccionarios dentro de las distintas columnas, así como el manejo de información faltante en la columna 'Churn', se optó por eliminar esta información indeterminada constataba menos del 5% general y resultaba irrelevante para el análisis.
#
# Finalmente, se le realizó un tratamiento a los distintos tipos del DF con la finalidad de mantener una mayor legibilidad al transformar objetos a valores enteros y flotantes, de esta manera en futuros análisis el procesamiento de la información resultará más directo y al tener un mismo térmio para valores de sí = 1 y no = 0, se facilita el entendimiento del DF.
# ________________________________________________________________________________
#
# ## Análisis de Resultados obtenidos
#
# El método inmediato para conocer un panorama general del estado de la información fue obtenido mediante el método describe(), donde se presenta un reporte donde se analizaron 7043 datos en todas las categorías numéricas, donde se presentó un promedio de abandono del 26.53%, la participación de 16.21% de ciudadanos senior, un 48.3% de parejas, así como un 29.95% de dependientes.
#
# Con esta información presente, se realizaron distintos análisis de estancia o abandono según categorías como género del cliente, ciudadano senior, método de pago y el total gastado. Dentro de estos análisis de comprobó que la magnitud de abandono entre hombres y mujeres es similar, sin embargo el índice de evasión es ligeramente mayor en el caso del género femenino. Por otro lado, los ciudadanos no senior representan la mayor clientela dentro de la empresa, este tipo de ciudadanos cuenta con una mayor cantidad absoluta de evasión con respecto a los ciudadanos senior, sin embargo, se demostró que alrededor de un 40% de los ciudadanos senior decidieron abandonar la empresa.
#
# Dentro del análisis de permanencia por tipo de contrato, se observó que los clientes que cuentan con un contrato mes a mes predominan dentro de la empresa, sin embargo, de igual manera son los que cuentan con mayor tendencia a abandonarla, ya que son el grupo con mayor tasa proporcional de abandono, así como la mayor magintud de desersión. Del mismo modo, se observó que el caso de planes de dos años presentan una mejor retención de clientela, seguido por los contratos de un año.
#
# Del análisis de abandonos según el estado civíl, se observa que existe una mayor retención en el caso de clientes con parejas, mientras que los clientes solteros tienden con mayor frecuencia a dejar de la empresa.
#
# Un punto muy fuerte se adquirió mediante el análisis de abandono según el método de pago, donde se arrojó que el método con mayor índice de abandono es el pago mediante cheques electrónicos, mientras que el método con menor abandono el la tarjeta de crédito, seguido por transferencias bancarias y cheques por correo.
#
# En el análisis numérico se revisó la distribución del abandono según el total gastado en la empresa, donde la mayor parte de las personas que abandonan la empresa se encuentran en gastos totales muy bajos, siendo clientes los clientes que han gastado al menos 6000 pesos valores atípicos, mientras que más del 75% de las personas que abandonan se encuentran por debajo de los 3000 pesos. Caso contrario, se observa que el 75% de las personas que permanecieron se encuentran por debajo de un rango de 4200 pesos.
#
# Finalmente, el análisis de gasto mensual y gasto diario demuestran que los clientes que abandonan cuentan con una tasa mayor que los que permanecen, sin embargo, la tendencia de abandonar o permanecer en el 75% de ambos casos se mantiene muy próxima.
#
# ________________________________________________________________________________
#
# ## Conclusiones
#
# Mediante el análisis de resultados realizado previamente, se determinó que los clientes con mayor tasa de abandono cuentan con las siguientes características Senior, proporcionalmente hablando, con un contrato de mes a mes, solteros, método de pago de tipo cheque electrónico, con baja inversión total y con gastos mensuales o diarios más elevados.
#
# La estrategia que se propone para evitar la desersión de mayor clientela radica en hacer planes más atractivos para los senior y no senior, pues aunque proporcionalmente los senior cuentan con mayor tasa de abandono, la magnitud de no senior que abandonan de igual manera es bastante significativa ya que representa más mercado que los clientes senior.
#
# Por otro lado, se recomienda facilitar el cambio del método de pago, principalmente de los clientes de cheque electrónico, así como buscar el motivo por el cuál no les agrada tanto este método para tomar acciones correctivas.
#
# Finalmente, se deberá buscar reducir los gastos diarios y mensuales de los clientes mediante promociones o incentivos como campañas de lealtad, de igual manera, se deberá buscar una forma para que su inversión total sea mayor mediante contratos más extensos, pues se demostró que los clientes con planes de mayor duración cuentan con un índice de abandono muy bajo.
#
# Se recomienda a los ejecutivos de la empresa TelecomX considerar seriamente las propuestas proporcionadas y tomar acción inmediata, ya que los datos demostraron actualmente al menos el 26.53% de la clientela ya abandonó la empresa, sin considerar a aquellos clientes con información faltante.
